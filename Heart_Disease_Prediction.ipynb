# %%
import keras

# %%
from keras.models import Sequential
obj = Sequential()   #Model Creation

# %%
from keras.layers import Dense

# %%
import pandas as pd

dt = pd.read_csv('/content/heart.csv')   #Data Loading
dt.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dt.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.132696 -0.390227  0.088163  0.208137 -0.169105  0.271551
# sex      -0.055117 -0.049365  0.139157  0.084687 -0.026666  0.111729
# cp        0.043581  0.306839 -0.401513 -0.174733  0.131633 -0.176206
# trestbps -0.123794 -0.039264  0.061197  0.187434 -0.120445  0.104554
# chol     -0.147410 -0.021772  0.067382  0.064880 -0.014248  0.074259
# fbs      -0.104051 -0.008866  0.049261  0.010859 -0.061902  0.137156
# restecg   1.000000  0.048411 -0.065606 -0.050114  0.086086 -0.078072
# thalach   0.048411  1.000000 -0.380281 -0.349796  0.395308 -0.207888
# exang    -0.065606 -0.380281  1.000000  0.310844 -0.267335  0.107849
# oldpeak  -0.050114 -0.349796  0.310844  1.000000 -0.575189  0.221816
# slope     0.086086  0.395308 -0.267335 -0.575189  1.000000 -0.073440
# ca       -0.078072 -0.207888  0.107849  0.221816 -0.073440  1.000000
# thal     -0.020504 -0.098068  0.197201  0.202672 -0.094090  0.149014
# target    0.134468  0.422895 -0.438029 -0.438441  0.345512 -0.382085
#
#               thal    target
# age       0.072297 -0.229324
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.059276 -0.138772
# chol      0.100244 -0.099966
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.098068  0.422895
# exang     0.197201 -0.438029
# oldpeak   0.202672 -0.438441
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %%
dt = dt.drop(['chol','fbs'],axis=1)

# %%
dt.tail(1)
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal  target
# 1024     3       0

# %%
x = dt.iloc[:,0:11]   #Feature Selection
y = dt['target']

# %%
x
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 0      52    1   0       125        1      168      0      1.0      2   2
# 1      53    1   0       140        0      155      1      3.1      0   0
# 2      70    1   0       145        1      125      1      2.6      0   0
# 3      61    1   0       148        1      161      0      0.0      2   1
# 4      62    0   0       138        1      106      0      1.9      1   3
# ...   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..
# 1020   59    1   1       140        1      164      1      0.0      2   0
# 1021   60    1   0       125        0      141      1      2.8      1   1
# 1022   47    1   0       110        0      118      1      1.0      1   1
# 1023   50    0   0       110        0      159      0      0.0      2   0
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal
# 0        3
# 1        3
# 2        3
# 3        3
# 4        2
# ...    ...
# 1020     2
# 1021     3
# 1022     2
# 1023     2
# 1024     3
#
# [1025 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split   #Data Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b238e9c7c0d1> in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split   #Data Split
# ----> 2 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)
#
# NameError: name 'x' is not defined

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1025, 11) (1025,) (768, 11) (257, 11) (768,) (257,)

# %%
obj.add(Dense(units=11,activation='relu'))  #Model Architecture

# %%
obj.add(Dense(units=5,activation='relu'))

# %%
obj.add(Dense(units=1,activation='sigmoid'))

# %%
obj.build(input_shape=(None,11))

# %%
obj.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198 (792.00 B)
#  Trainable params: 198 (792.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
obj.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
obj.fit(x_train,y_train,epochs=100,batch_size=8,steps_per_epoch=x_train.shape[0]//8)
# Out:
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5558 - loss: 9.6590
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7327 - loss: 0.5734
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7413 - loss: 0.5424
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7204 - loss: 0.5671
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7752 - loss: 0.4775
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7729 - loss: 0.4841
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7724 - loss: 0.4480
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7914 - loss: 0.4422
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8112 - loss: 0.4596
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7756 - loss: 0.4582
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8276 - loss: 0.4168
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7882 - loss: 0.4278
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7988 - loss: 0.4130
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8141 - loss: 0.3955
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8381 - loss: 0.3963
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8187 - loss: 0.4104
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8367 - loss: 0.3848
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8192 - loss: 0.4040
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8118 - loss: 0.4084
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8084 - loss: 0.4349
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8397 - loss: 0.3596
# Epoch 22/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8359 - loss: 0.4012
# Epoch 23/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8455 - loss: 0.3712
# Epoch 24/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8051 - loss: 0.4128
# Epoch 25/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8188 - loss: 0.3996
# Epoch 26/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8476 - loss: 0.3743
# Epoch 27/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8395 - loss: 0.3981
# Epoch 28/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8391 - loss: 0.3668
# Epoch 29/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8484 - loss: 0.3643
# Epoch 30/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.3983
# Epoch 31/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8290 - loss: 0.3967
# Epoch 32/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8399 - loss: 0.3749
# Epoch 33/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8638 - loss: 0.3672
# Epoch 34/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8093 - loss: 0.4155
# Epoch 35/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8291 - loss: 0.4137
# Epoch 36/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8463 - loss: 0.3454
# Epoch 37/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8218 - loss: 0.4017
# Epoch 38/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8412 - loss: 0.3960
# Epoch 39/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8227 - loss: 0.4035
# Epoch 40/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8118 - loss: 0.3686
# Epoch 41/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8524 - loss: 0.3633
# Epoch 42/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8397 - loss: 0.3968
# Epoch 43/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7942 - loss: 0.4531
# Epoch 44/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8196 - loss: 0.3986
# Epoch 45/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8237 - loss: 0.3783
# Epoch 46/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8384 - loss: 0.3771
# Epoch 47/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8341 - loss: 0.3872
# Epoch 48/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8224 - loss: 0.3917
# Epoch 49/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8578 - loss: 0.3457
# Epoch 50/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8236 - loss: 0.4166
# Epoch 51/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8255 - loss: 0.4312
# Epoch 52/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8426 - loss: 0.3623
# Epoch 53/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8044 - loss: 0.4283
# Epoch 54/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8247 - loss: 0.4045
# Epoch 55/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8247 - loss: 0.3664
# Epoch 56/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8448 - loss: 0.3680
# Epoch 57/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8694 - loss: 0.3434
# Epoch 58/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8413 - loss: 0.3533
# Epoch 59/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8301 - loss: 0.3786
# Epoch 60/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8365 - loss: 0.3868
# Epoch 61/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8481 - loss: 0.3726
# Epoch 62/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8370 - loss: 0.3617
# Epoch 63/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8097 - loss: 0.3971
# Epoch 64/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8217 - loss: 0.3683
# Epoch 65/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8267 - loss: 0.3700
# Epoch 66/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8062 - loss: 0.4257
# Epoch 67/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8439 - loss: 0.3471
# Epoch 68/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8492 - loss: 0.3687
# Epoch 69/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8396 - loss: 0.3892
# Epoch 70/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8178 - loss: 0.3960
# Epoch 71/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8106 - loss: 0.3993
# Epoch 72/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8228 - loss: 0.3746
# Epoch 73/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8368 - loss: 0.3972
# Epoch 74/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8373 - loss: 0.3865
# Epoch 75/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.3110
# Epoch 76/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8567 - loss: 0.3623
# Epoch 77/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8204 - loss: 0.3976
# Epoch 78/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8448 - loss: 0.3964
# Epoch 79/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.4035
# Epoch 80/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8239 - loss: 0.3755
# Epoch 81/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8283 - loss: 0.3908
# Epoch 82/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8464 - loss: 0.3815
# Epoch 83/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8256 - loss: 0.3659
# Epoch 84/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8338 - loss: 0.3743
# Epoch 85/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8297 - loss: 0.3858
# Epoch 86/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8498 - loss: 0.3629
# Epoch 87/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8482 - loss: 0.3403
# Epoch 88/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7992 - loss: 0.4382
# Epoch 89/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8635 - loss: 0.3510
# Epoch 90/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8276 - loss: 0.4234
# Epoch 91/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8346 - loss: 0.3697
# Epoch 92/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8393 - loss: 0.3899
# Epoch 93/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8499 - loss: 0.3492
# Epoch 94/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8435 - loss: 0.3493
# Epoch 95/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8473 - loss: 0.3631
# Epoch 96/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8426 - loss: 0.3792
# Epoch 97/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3638
# Epoch 98/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8373 - loss: 0.3914
# Epoch 99/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8469 - loss: 0.3665
# Epoch 100/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8041 - loss: 0.3860

# %%
y_pred = obj.predict(x_test)
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d489a4bcd60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score  #Evaluation
accuracy_score(y_test,y_pred)
# Out:
# 0.8171206225680934

# %%
obj.save('heart.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x_train
# Out:
#      age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  thal
# 787   51    1   0       140        1      122      1      4.2      1   3     3
# 216   65    1   0       135        0      127      0      2.8      1   1     3
# 58    67    1   2       152        0      150      0      0.8      1   0     3
# 553   53    1   2       130        0      152      0      1.2      0   0     2
# 633   61    1   0       138        0      125      1      3.6      1   1     2
# ..   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..   ...
# 413   70    1   0       130        0      109      0      2.4      1   3     2
# 343   52    1   2       172        1      162      0      0.5      2   0     3
# 264   58    0   0       170        0      146      1      2.8      1   2     1
# 304   52    0   2       136        0      169      0      0.1      1   0     2
# 814   62    1   1       128        0      140      0      0.0      2   0     2
#
# [768 rows x 11 columns]

# %%
x_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')
